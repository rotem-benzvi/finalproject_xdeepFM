# %%
from google.colab import  drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## **1. load all the results dataframes - Avazu dataset**

# %%
df_DeepFM_full_avazu = pd.read_pickle('/content/drive/MyDrive/RCSYS_finalproject/results/final_results_DeepFM_avazu_original.pkl')

# %%
df_DeepFM_best = df_DeepFM_full_avazu.loc[df_DeepFM_full_avazu.test_AUC.nlargest(10).index]
df_DeepFM_best.reset_index(inplace=True)
df_DeepFM_best.drop(['index'], axis=1,inplace=True)
df_DeepFM_best
# Out:
#                Model_name  ...                                        Val_History
# 0  DeepFM_avazu_original6  ...  [0.39671619723746004, 0.3905471291728129, 0.38...
# 1  DeepFM_avazu_original6  ...  [0.39680521196086793, 0.39056324001158527, 0.3...
# 2  DeepFM_avazu_original6  ...  [0.39678328231101656, 0.3905473993490924, 0.38...
# 3   DeepFM_avazu_original  ...           [0.3915027846992101, 0.3867972775850718]
# 4   DeepFM_avazu_original  ...          [0.39172824526520683, 0.3867510228553059]
# 5   DeepFM_avazu_original  ...           [0.3923755010894032, 0.3864399396857199]
# 6   DeepFM_avazu_original  ...           [0.3924585476633911, 0.3864376437352965]
# 7  DeepFM_avazu_original2  ...         [0.39335373134570223, 0.38611832728860956]
# 8  DeepFM_avazu_original2  ...          [0.3933082956638255, 0.38613151826370024]
# 9   DeepFM_avazu_original  ...          [0.39316903871463527, 0.3863542735106467]
#
# [10 rows x 9 columns]

# %% [markdown]
# ## **1. load all the results dataframes - Criteo dataset**

# %%
df_DeepFM_full = pd.read_pickle('/content/drive/MyDrive/RCSYS_finalproject/results/final_results_DeepFM_criteo_original.pkl')
df_xDeepFM_full = pd.read_pickle('/content/drive/MyDrive/RCSYS_finalproject/results/final_results_xDeepFM_criteo_original.pkl')
df_SEDeepFM_full = pd.read_pickle('/content/drive/MyDrive/RCSYS_finalproject/results/final_results_SExDeepFM_criteo_original.pkl')

# %%
df_DeepFM_best = df_DeepFM_full.loc[df_DeepFM_full.test_AUC.nlargest(10).index]
df_DeepFM_best.reset_index(inplace=True)
df_DeepFM_best.drop(['index'], axis=1,inplace=True)
df_DeepFM_best
# Out:
#                 Model_name  ...                                        Val_History
# 0   DeepFM_criteo_original  ...           [0.4726723529183396, 0.4703654538634312]
# 1   DeepFM_criteo_original  ...          [0.4727966885613441, 0.47042745595614827]
# 2   DeepFM_criteo_original  ...         [0.47373657055590374, 0.47058491420064424]
# 3   DeepFM_criteo_original  ...          [0.4739103798275598, 0.47067839853394283]
# 4   DeepFM_criteo_original  ...         [0.47360136354955384, 0.47086380910510045]
# 5   DeepFM_criteo_original  ...         [0.47435803051211106, 0.47097891902910954]
# 6   DeepFM_criteo_original  ...          [0.4751891166303552, 0.47126020370637334]
# 7   DeepFM_criteo_original  ...           [0.4752279335239855, 0.4712754954891547]
# 8   DeepFM_criteo_original  ...          [0.4753681830086721, 0.47140401541877147]
# 9  DeepFM_criteo_original2  ...  [0.4752279335239855, 0.4712754954891547, 0.473...
#
# [10 rows x 9 columns]

# %%
df_xDeepFM_best = df_xDeepFM_full.loc[df_xDeepFM_full.test_AUC.nlargest(10).index]
df_xDeepFM_best.reset_index(inplace=True)
df_xDeepFM_best.drop(['index'], axis=1,inplace=True)
df_xDeepFM_best
# Out:
#                  Model_name  ...                                 Val_History
# 0  xDeepFM_criteo_original2  ...   [0.46055978053790897, 0.4752963508559501]
# 1   xDeepFM_criteo_original  ...  [0.47281308287754165, 0.47128635312308426]
# 2   xDeepFM_criteo_original  ...   [0.4728333426390899, 0.47131172187512765]
# 3  xDeepFM_criteo_original2  ...   [0.4719958778507302, 0.47164839720463475]
# 4   xDeepFM_criteo_original  ...  [0.47401375834015674, 0.47122429182098946]
# 5   xDeepFM_criteo_original  ...  [0.47400566912502434, 0.47120088244759234]
# 6  xDeepFM_criteo_original2  ...    [0.4720833996343782, 0.4717130273691052]
# 7   xDeepFM_criteo_original  ...    [0.4741320924052416, 0.4713636145751779]
# 8   xDeepFM_criteo_original  ...   [0.4731234431542595, 0.47163777616782565]
# 9  xDeepFM_criteo_original2  ...    [0.4726474029242465, 0.4722987774472346]
#
# [10 rows x 9 columns]

# %%
df_SExDeepFM_best = df_SEDeepFM_full.loc[df_SEDeepFM_full.test_AUC.nlargest(10).index]
df_SExDeepFM_best.reset_index(inplace=True)
df_SExDeepFM_best.drop(['index'], axis=1,inplace=True)
df_SExDeepFM_best
# Out:
#                    Model_name  ...                                        Val_History
# 0  SExDeepFM_criteo_original4  ...           [0.4713882595096434, 0.4693137999152574]
# 1  SExDeepFM_criteo_original4  ...          [0.47149386988017294, 0.4693570443950657]
# 2   SExDeepFM_criteo_original  ...           [0.4724112475718198, 0.4695519087177809]
# 3   SExDeepFM_criteo_original  ...           [0.4723581732870735, 0.4695051410562519]
# 4   SExDeepFM_criteo_original  ...          [0.4728097971615117, 0.46984757679654954]
# 5  SExDeepFM_criteo_original4  ...         [0.47226828134859034, 0.47000455407771463]
# 6   SExDeepFM_criteo_original  ...          [0.4736989501162122, 0.47012069483449925]
# 7   SExDeepFM_criteo_original  ...           [0.4736544025235037, 0.4701039952710781]
# 8   SExDeepFM_criteo_original  ...           [0.4738775648112351, 0.4702672312827613]
# 9   SExDeepFM_criteo_original  ...  [0.4736989501162122, 0.47012069483449925, 0.47...
#
# [10 rows x 9 columns]

# %% [markdown]
# ## **Plot all the train and validation loss history of one model.**

# %%
import matplotlib.pyplot as plt
import numpy as np


lines = df_DeepFM_full.Train_History
plt.figure(figsize=(16,6))

for l in lines:
    plt.plot(l)

plt.xticks(np.arange(4))
plt.title('')
plt.xlabel('Iterations')
plt.ylabel('BCE')
plt.show();

# %%
lines = df_DeepFM_full.Val_History
plt.figure(figsize=(16,6))

for l in lines:
    plt.plot(l)

plt.xticks(np.arange(4))
plt.title('')
plt.xlabel('Iterations')
plt.ylabel('BCE')
plt.show();

# %% [markdown]
# ## **Plot only the 15 best resutlt - train and validation loss history of one model.**

# %%
lines_train = df_DeepFM_full.Train_History
lines_val = df_DeepFM_full.Val_History

lines_train = lines_train[df_DeepFM_full.test_LogLoss.nsmallest(15).index]
lines_val = lines_val[df_DeepFM_full.test_LogLoss.nsmallest(15).index]
plt.figure(figsize=(12,5))

for l in lines_train:
    plt.plot(l)

plt.xticks(np.arange(4))
plt.title('')
plt.xlabel('Iterations')
plt.ylabel('BCE')
plt.show();

# %%
for l in lines_val:
  plt.plot(l)

plt.xticks(np.arange(4))
plt.title('')
plt.xlabel('Iterations')
plt.ylabel('BCE')
plt.show();

# %%
def save_loss_figure(train_loss,val_loss,model_name,batch_size,epochs,lr,l2_reg_dnn):
  plt.figure(figsize=(12,5))
  plt.plot(train_loss)
  plt.plot(val_loss)
  plt.xticks(np.arange(len(train_loss)+1))
  plt.title('')
  plt.xlabel('Iterations')
  plt.ylabel('binary_crossentropy')
  plt.legend(['Train Loss', 'Validation Loss'])
  #figure_name = "/content/drive/MyDrive/RCSYS_finalproject/results/" + "figure_loss_" + model_name +'_bs_' + str(batch_size) + '_epochs_' + str(epochs) +'_lr_'+ str(lr)[2:] + '_reg_' + str(l2_reg_dnn)[2:] + '.png'
  #plt.savefig(figure_name)
  plt.show()

# %%
fig, axes = plt.subplots(nrows=10, ncols=2, figsize=(5, 33))
st = fig.suptitle("deepFM - train and validation loss of 10 best result", fontsize=20,y=0.92,x=1.5)

for index, row in df_DeepFM_best.iterrows():
  plt.subplots_adjust(right = 3)
  axes[index][0].plot(row.Val_History,color='orange')
  axes[index][1].plot(row.Train_History)
  #fig.tight_layout()

  #axes[0].xticks(np.arange(len(row.Val_History)+1))
  #axes[1].xticks(np.arange(len(row.Val_History)+1))

  axes[index][0].set_title(row.Model_name + ' - batch size: ' +str(row.Batch_Size) +', iterations: ' + str(row.Iterations) +', lr: '+ str(row.Learning_Rate) +', reg: ' + str(row.DNN_Reg))
  axes[index][0].set_xlabel('Iterations')
  axes[index][0].set_ylabel('binary_crossentropy')
  axes[index][0].legend(['Validation Loss'])

  axes[index][1].set_title(row.Model_name + ' - batch size: ' +str(row.Batch_Size) +', iterations: ' + str(row.Iterations) +', lr: '+ str(row.Learning_Rate) +', reg: ' + str(row.DNN_Reg))
  axes[index][1].set_xlabel('Iterations')
  axes[index][1].set_ylabel('binary_crossentropy')
  axes[index][1].legend(['Train Loss'])

  #figure_name = "/content/drive/MyDrive/RCSYS_finalproject/results/" + "figure_loss_" + model_name +'_bs_' + str(batch_size) + '_epochs_' + str(epochs) +'_lr_'+ str(lr)[2:] + '_reg_' + str(l2_reg_dnn)[2:] + '.png'
  #plt.savefig(figure_name)
  #plt.show()
  #save_loss_figure(row.Train_History,row.Val_History,row.Model_name,row.Batch_Size,row.Iterations,row.Learning_Rate,row.DNN_Reg)

#fig.subplots_adjust(top=2)
plt.subplots_adjust(hspace=0.5, wspace=0.3)
figure_name = "/content/drive/MyDrive/RCSYS_finalproject/results/DeepFM_loss_Criteo.png"
plt.savefig(figure_name,bbox_inches='tight')
plt.show()

# %%
df_xDeepFM1 = pd.read_pickle('/content/drive/MyDrive/RCSYS_finalproject/results/results_xDeepFM_criteo_original.pkl')
df_xDeepFM2 = pd.read_pickle('/content/drive/MyDrive/RCSYS_finalproject/results/results_xDeepFM_criteo_original2.pkl')

# %%
df_xDeepFM_full = pd.concat([df_xDeepFM2,df_xDeepFM1])
df_xDeepFM_full.reset_index(inplace=True)
df_xDeepFM_full.drop(['index'], axis=1,inplace=True)
df_xDeepFM_full.to_pickle('/content/drive/MyDrive/RCSYS_finalproject/results/final_results_xDeepFM_criteo_original.pkl')

# %%
df_xDeepFM_full = pd.read_pickle('/content/drive/MyDrive/RCSYS_finalproject/results/final_results_xDeepFM_criteo_original.pkl')
